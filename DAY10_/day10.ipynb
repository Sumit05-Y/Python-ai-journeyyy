# %% [markdown]
# <a href="https://colab.research.google.com/github/Sumit05-Y/Python-ai-journeyyy/blob/main/day10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
python_student ={"Ram","Sita","Hari","Shyam","Geeta"}
ml_student= {"ABC1","DEF2","GHI3","Hari","Sita"}
both = python_student & ml_student
print(both)
either = python_student | ml_student
print(either)
python_only  = python_student - ml_student
print(python_only)
exclusive = python_student ^ ml_student
print(exclusive)
# Out:
# {'Sita', 'Hari'}
# {'Sita', 'GHI3', 'ABC1', 'DEF2', 'Ram', 'Geeta', 'Hari', 'Shyam'}
# {'Ram', 'Geeta', 'Shyam'}
# {'Ram', 'Geeta', 'GHI3', 'ABC1', 'Shyam', 'DEF2'}

# %%
tag = {"python","ai"}
tag.add("ml")
print(tag)
#tag.remove("ml")
print(tag)
tag.discard("java")
print(tag)
print("python" in tag)
# Out:
# {'python', 'ml', 'ai'}
# {'python', 'ml', 'ai'}
# {'python', 'ml', 'ai'}
# True
