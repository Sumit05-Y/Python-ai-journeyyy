# %% [markdown]
# <a href="https://colab.research.google.com/github/Sumit05-Y/Python-ai-journeyyy/blob/main/DAY1_and_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# !r denotes string ho bhne '' maa aunxa haina bhne esai aunxa

# %%
name = "sumit sah"
age = 17
height=6.2
is_student=True
middle_name=None
frequency=3+4j
for v in [name , age , height , is_student , middle_name , frequency]:
  print(f"Value:  {v!r:<20}Type:{type(v).__name__}")
# Out:
# Value:  'sumit sah'         Type:str
# Value:  17                  Type:int
# Value:  6.2                 Type:float
# Value:  True                Type:bool
# Value:  None                Type:NoneType
# Value:  (3+4j)              Type:complex

# %%
print(f"hello world")
# Out:
# hello world

# %%
print("hello world")
# Out:
# hello world

# %%
name = "sumit"
age = 17

print("hello , i am " + name + "and i am "+  str(age) + "years old")
# Out:
# hello , i am sumitand i am 17years old

# %%
name= "sumit"
lucky_number="5"
print("i am"+name+"and my lucky number is"+ str(lucky_number))
print(f"i am {name},my lucky number is {lucky_number}")
# Out:
# i amsumitand my lucky number is5
# i am sumit,my lucky number is 5

# %%
isinstance(12,int)
# Out:
# True

# %%
boolean is branch of int as true is 1 and false is 0

# %%
print(True + True)
# Out:
# 2

# %%
print(type(True))
print(type(True).__name__)
# Out:
# <class 'bool'>
# bool

# %% [markdown]
# camelcase=UserName (eg c+ ma pinMode)
# snake_case=User_name ( eg python ma)
# variable tips

# %% [markdown]
# TUPLE UNPACKING

# %%
a=10
b=20
a,b=b,a
print(a,b)
# Out:
# 20 10

# %% [markdown]
# OR LEY JAILE TRUTHY VALUE RETURN GARXA JASTAI TALA DEFAULT MA TRUTHY VALUE XA SO TESLE DEFAULT DINXA 0 MA FALSE VALUE XA

# %%
print("default" or 0)
# Out:
# default

# %% [markdown]
# and ma chai truthy hunu parxa duita ki ta falsy hunu parxa if pailo falsy xa bhne tei print hunxa truthy xa bhne tespaxi ko truthy xa ki nai herxa ani arko print hunxa

# %%
print("hello" and 0)
# Out:
# 0

# %% [markdown]
# PEMDAS (BODMAS JASTAI SANO MA)

# %%
age=int(input("enter age:"))
print(age+1)
# Out:
# enter age:65
# 66

# %% [markdown]
# error handle garne esari

# %%
try:
  age = int(input("enter your age"))
  print(f"next year your age will be {age+1}")
except ValueError:
  print("invalid input.please enter your digits only")

# %% [markdown]
# :, esle thousand samma ma comma dinxa
#
# ---
# : 05d ley total ma 5 digit parxa

# %%
price=1000
print(f"The price is {price:,}")
print(f"{price:05d}")
# Out:
# The price is 1,000
# 01000

# %% [markdown]
# :>100 ley left ma space dinxa

# %%
i = "sumit"
print(f"{i:>100}")
# Out:
#                                                                                                sumit

# %% [markdown]
# BUILD A USD CURRENCY CONVERTER . USER ENTERS AN AMOUNT IN USD. PRINT THE EQUIVALENT IN NRS , EUR AND GBP. USE ALL_CAPS FOR YOUR EXCHANGE RATE CONSTANTS. FORMAT THE OUTPUT WITH COMMA SEPARATORS AND 2 DECIMAL PLACES

# %%
print("say \"hello\"")
# Out:
# say "hello"
