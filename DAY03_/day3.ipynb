# %% [markdown]
# <a href="https://colab.research.google.com/github/Sumit05-Y/Python-ai-journeyyy/blob/main/day3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
temp=20
if temp >30:
  print("GARMIIIIII")
elif temp > 20:
  print("GARMIII")
elif temp > 10:
  print("THORAI CHISO")
else:
  print("CHISO JACKET LAGA")
# Out:
# THORAI CHISO

# %%
user_input=input("enter any thing")
if user_input:
  print(f"user entered {user_input}")
else:
  print(f"you wrote nothing")
# Out:
# enter any thingsululu
# user entered sululu

# %%
age=int(input("enter your age"))
has_id=input("ENTER True or False")
if age >= 18:
  if has_id== True:
    print(f"KHATRA HERO RAIXAS CHALA BIKE")
  else:
    print(f"Id leu babu")
else:
  print("thulo bhaisak paila")
# Out:
# enter your age18
# ENTER True or FalseFalse
# KHATRA HERO RAIXAS CHALA BIKE

# %% [markdown]
# TERNARY OPERATOR

# %%
marks = 20
result="pass" if marks >= 25 else "fail"
print(result)
# Out:
# fail

# %%
age = int(input("enter age"))
status = "Adult" if age >=18 else "Bachha"
print(status)
# Out:
# enter age8
# Bachha

# %%
cart_total=float(input("Enter total $ "))
shipping_cost=0 if cart_total > 100 else 15
print(f"your shipping cost is $ {shipping_cost}")
# Out:
# Enter total $ 1234
# your shipping cost is $ 0

# %%
scores = [ 25, 15, 24, 45, 32, 1]
grades = []
for i in scores:
  grades.append("pass") if i >=20 else grades.append("fail")
print(grades)
# Out:
# ['pass', 'fail', 'pass', 'pass', 'pass', 'fail']
