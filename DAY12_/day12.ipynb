# %% [markdown]
# <a href="https://colab.research.google.com/github/Sumit05-Y/Python-ai-journeyyy/blob/main/day12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#shared default argument
def add_item(item,cart=[]):
  cart.append(item)
  return cart
order=add_item("Shoes")
print(order)


order1=add_item("socks")
print(order1)
# Out:
# ['Shoes']
# ['Shoes', 'socks']

# %%
#solution of it
def add_item(item,cart=None):
  if cart is None:
    cart=[]
    cart.append(item)
    return cart
order=add_item("Shoes")
print(order)


order1=add_item("socks")
print(order1)
# Out:
# ['Shoes']
# ['socks']
