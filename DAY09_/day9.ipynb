# %% [markdown]
# <a href="https://colab.research.google.com/github/Sumit05-Y/Python-ai-journeyyy/blob/main/day9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
point = (10,20,30,40)
print(point[0:3])
print(point[2:0:-1])
# Out:
# (10, 20, 30)
# (30, 20)

# %%
point = (1,2,3)
new_data=(4,)
new_point= point + new_data
print(new_point)
# Out:
# (1, 2, 3, 4)

# %% [markdown]
# tuple list ma change garyo

# %%
my_tuple = ("apple", "banana")

# Convert to list
temp_list = list(my_tuple)

# Add elements safely
temp_list.append("orange")

# Convert back to tuple
my_tuple = tuple(temp_list)
print(my_tuple)  # Output: ('apple', 'banana', 'orange')

# %%
point = (10,20) #unpacking tuple
x,y= point
print(x)
print(y)
# Out:
# 10
# 20

# %%
point = [1,2,3,4]
a,b,c,d= point
print(a,b,c,d)
# Out:
# 1 2 3 4

# %%
tags = {"python","ai","journey","ml","ai"}
print(tags)
# Out:
# {'ai', 'journey', 'python', 'ml'}

# %%
del set
numbers=[1,2,3,3,1,2,3,4,5,6,7,5]
unique_numbers = set(numbers)
print(unique_numbers)
# Out:
# {1, 2, 3, 4, 5, 6, 7}
