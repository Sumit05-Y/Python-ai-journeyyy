# %% [markdown]
# <a href="https://colab.research.google.com/github/Sumit05-Y/Python-ai-journeyyy/blob/main/day15filehandling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
f=open("demofile.txt")

# %%
f=open("test.txt","x")

# %%
with open("visitor.txt","w") as f:
  f.write("---------VISITOR LOG--------------")

# %%
with open("visitor.txt","a") as f:
  user=input("Enter guest name :")
  f.write(f"\n {user}")
# Out:
# Enter guest name :Hello3

# %%
with open("visitor.txt") as f:
  print(f.read())
# Out:
# ---------VISITOR LOG--------------
#  Hello1
#  Hello2
#  Hello3
